# %% [markdown]
# <a href="https://colab.research.google.com/github/SupidchayaTangkidwanich/-prj/blob/main/Dataset_CDD_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive # เชื่อมเข้ากับ Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %% [markdown]
# # training

# %%
train = r'/content/drive/My Drive/Dataset_CDD_v4/training'

# %%
import os # os เอาไว้จัดการไฟล์และ path 

files = [] # สร้างตัวแปรมารับค่าไว้ใน list ว่าง
for (path, dirnames, filenames) in os.walk(train): # os.walk คือ ทำงานสร้างชื่อไฟล์แต่ละไฟล์ ตามที่เก็บข้อมูล
    
    files.extend(os.path.join(path, name) for name in filenames) # extend  ใช้เพื่อรวม list # คำสั่งเชื่อมส่วนประกอบของ path ที่ประกอบด้วย directory หรือ file เพื่อสร้าง path หรือ URL ที่รองรับการทำงานบนระบบปฏิบัติการต่างๆ

print(files) # แสดงผลลัพธ์
# Out:
# ['/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0010.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0011.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0016.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0018.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0218.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0222.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0255.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0296.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0308.jpeg', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0383.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0384.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0301.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0323.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/training/Severe/p3/0380.JPEG', '/c
# ...

# %%
training = pd.DataFrame({'Path_Name':files})
training
# Out:
#                                              Path_Name
# 0    /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 1    /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 2    /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 3    /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 4    /content/drive/My Drive/Dataset_CDD_v4/trainin...
# ..                                                 ...
# 729  /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 730  /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 731  /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 732  /content/drive/My Drive/Dataset_CDD_v4/trainin...
# 733  /content/drive/My Drive/Dataset_CDD_v4/trainin...
#
# [734 rows x 1 columns]

# %%
list_path = list(training['Path_Name']) # เก็บที่อยู่ของภาพในรูปแบบตาราง โดยชื่อว่า list_path ซึ่ง list(ชื่อตาราง['ชื่อคอลัมน์'])
class_list = list() # สร้างตัวแปร class_list มาเก็บ list ว่าง
for i in list_path: # วนลูปใน list_path
    res = i.split('/') # split ใช้สำหรับแยก โดยในที่นี้แยกด้วย / แล้วตั้งชื่อว่า res
    #print(res[6]) # แสดงผลลัพธ์ของ res ตัวที่ 5 คือตำเเหน่งที่เราต้องการ 
    class_list.append(res[6]) # append  คำสั่งเพิ่มข้อมูลลงใน List
    
training['Degree'] = class_list # ตั้งชื่อคอลัมน์ว่า id ในตาราง pathname โดยนำค่าใน class_list มาใส่

# %%
training
# Out:
#                                              Path_Name  Degree
# 0    /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 1    /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 2    /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 3    /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 4    /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# ..                                                 ...     ...
# 729  /content/drive/My Drive/Dataset_CDD_v4/trainin...   Minor
# 730  /content/drive/My Drive/Dataset_CDD_v4/trainin...   Minor
# 731  /content/drive/My Drive/Dataset_CDD_v4/trainin...   Minor
# 732  /content/drive/My Drive/Dataset_CDD_v4/trainin...   Minor
# 733  /content/drive/My Drive/Dataset_CDD_v4/trainin...   Minor
#
# [734 rows x 2 columns]

# %% [markdown]
# # validation

# %%
validation = r'/content/drive/My Drive/Dataset_CDD_v4/validation'

# %%
import os # os เอาไว้จัดการไฟล์และ path 

files = [] # สร้างตัวแปรมารับค่าไว้ใน list ว่าง
for (path, dirnames, filenames) in os.walk(validation): # os.walk คือ ทำงานสร้างชื่อไฟล์แต่ละไฟล์ ตามที่เก็บข้อมูล
    
    files.extend(os.path.join(path, name) for name in filenames) # extend  ใช้เพื่อรวม list # คำสั่งเชื่อมส่วนประกอบของ path ที่ประกอบด้วย directory หรือ file เพื่อสร้าง path หรือ URL ที่รองรับการทำงานบนระบบปฏิบัติการต่างๆ

print(files) # แสดงผลลัพธ์
# Out:
# ['/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p13/0022.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p13/0024.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p13/0025.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p13/0031.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p13/0036.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p13/0040.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p1/0013.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p11/0004.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p11/0014.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p12/0022.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p12/0041.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p10/0005.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation/Minor/p9/0034.JPEG', '/content/drive/My Drive/Dataset_CDD_v4/validation
# ...

# %%
validation = pd.DataFrame({'Path_Name':files})
validation
# Out:
#                                             Path_Name
# 0   /content/drive/My Drive/Dataset_CDD_v4/validat...
# 1   /content/drive/My Drive/Dataset_CDD_v4/validat...
# 2   /content/drive/My Drive/Dataset_CDD_v4/validat...
# 3   /content/drive/My Drive/Dataset_CDD_v4/validat...
# 4   /content/drive/My Drive/Dataset_CDD_v4/validat...
# ..                                                ...
# 88  /content/drive/My Drive/Dataset_CDD_v4/validat...
# 89  /content/drive/My Drive/Dataset_CDD_v4/validat...
# 90  /content/drive/My Drive/Dataset_CDD_v4/validat...
# 91  /content/drive/My Drive/Dataset_CDD_v4/validat...
# 92  /content/drive/My Drive/Dataset_CDD_v4/validat...
#
# [93 rows x 1 columns]

# %%
list_path = list(validation['Path_Name']) # เก็บที่อยู่ของภาพในรูปแบบตาราง โดยชื่อว่า list_path ซึ่ง list(ชื่อตาราง['ชื่อคอลัมน์'])
class_list = list() # สร้างตัวแปร class_list มาเก็บ list ว่าง
for i in list_path: # วนลูปใน list_path
    res = i.split('/') # split ใช้สำหรับแยก โดยในที่นี้แยกด้วย / แล้วตั้งชื่อว่า res
    #print(res[6]) # แสดงผลลัพธ์ของ res ตัวที่ 5 คือตำเเหน่งที่เราต้องการ 
    class_list.append(res[6]) # append  คำสั่งเพิ่มข้อมูลลงใน List
    
validation['Degree'] = class_list # ตั้งชื่อคอลัมน์ว่า id ในตาราง pathname โดยนำค่าใน class_list มาใส่

# %%
validation
# Out:
#                                             Path_Name  Degree
# 0   /content/drive/My Drive/Dataset_CDD_v4/validat...   Minor
# 1   /content/drive/My Drive/Dataset_CDD_v4/validat...   Minor
# 2   /content/drive/My Drive/Dataset_CDD_v4/validat...   Minor
# 3   /content/drive/My Drive/Dataset_CDD_v4/validat...   Minor
# 4   /content/drive/My Drive/Dataset_CDD_v4/validat...   Minor
# ..                                                ...     ...
# 88  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 89  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 90  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 91  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 92  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
#
# [93 rows x 2 columns]

# %% [markdown]
# # รวมตาราง

# %%
Dataset_CDD_v4 = pd.concat([training,validation])
Dataset_CDD_v4
# Out:
#                                             Path_Name  Degree
# 0   /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 1   /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 2   /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 3   /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 4   /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# ..                                                ...     ...
# 88  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 89  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 90  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 91  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 92  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
#
# [827 rows x 2 columns]
