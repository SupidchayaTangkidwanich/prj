# %% [markdown]
# <a href="https://colab.research.google.com/github/SupidchayaTangkidwanich/-prj/blob/main/test_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive # เชื่อมเข้ากับ Drive
drive.mount('/content/drive')  # คลิกที่ลิงก์ -> เลือก E-mail -> ลงชื่อเข้าใช้ -> ก็อปโค้ด -> นำกลับมาวางในช่องว่าง -> กด enter
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
Rcar = r'/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1'

# %%
import os # os เอาไว้จัดการไฟล์และ path 

files = [] # สร้างตัวแปรมารับค่าไว้ใน list ว่าง
for (path, dirnames, filenames) in os.walk(Rcar): # os.walk คือ ทำงานสร้างชื่อไฟล์แต่ละไฟล์ ตามที่เก็บข้อมูล
    
    files.extend(os.path.join(path, name) for name in filenames) # extend  ใช้เพื่อรวม list # คำสั่งเชื่อมส่วนประกอบของ path ที่ประกอบด้วย directory หรือ file เพื่อสร้าง path หรือ URL ที่รองรับการทำงานบนระบบปฏิบัติการต่างๆ

print(files) # แสดงผลลัพธ์
# Out:
# ['/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0001.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0011.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0071.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0031.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0081.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0061.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0101.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0091.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0041.png', '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0021.png', '/content/drive/My Drive/unsup-car-dataset/frei
# ...

# %%
files
# Out:
# ['/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0001.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0011.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0071.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0031.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0081.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0061.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0101.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0091.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0041.png',
#  '/content/drive/My Drive/unsup-car-dataset/freiburg_static_cars_52_v1.1/car050/left-0021.png',
# ...

# %%
import pandas as pd

# %%
car = pd.DataFrame({'Path_Name':files}) # สร้างตารางคอลลัมม์ที่อยู่ของภาพโดยตั้งชื่อคอลลัมม์ว่า Path_name 
car #แสดงตาราง
# Out:
#                                               Path_Name
# 0     /content/drive/My Drive/unsup-car-dataset/frei...
# 1     /content/drive/My Drive/unsup-car-dataset/frei...
# 2     /content/drive/My Drive/unsup-car-dataset/frei...
# 3     /content/drive/My Drive/unsup-car-dataset/frei...
# 4     /content/drive/My Drive/unsup-car-dataset/frei...
# ...                                                 ...
# 5831  /content/drive/My Drive/unsup-car-dataset/frei...
# 5832  /content/drive/My Drive/unsup-car-dataset/frei...
# 5833  /content/drive/My Drive/unsup-car-dataset/frei...
# 5834  /content/drive/My Drive/unsup-car-dataset/frei...
# 5835  /content/drive/My Drive/unsup-car-dataset/frei...
#
# [5836 rows x 1 columns]

# %%
list_path = list(car['Path_Name']) # เก็บที่อยู่ของภาพในรูปแบบตาราง โดยชื่อว่า list_path ซึ่ง list(ชื่อตาราง['ชื่อคอลัมน์'])
class_list = list() # สร้างตัวแปร class_list มาเก็บ list ว่าง
for i in list_path: # วนลูปใน list_path
    res = i.split('/') # split ใช้สำหรับแยก โดยในที่นี้แยกด้วย / แล้วตั้งชื่อว่า res
    print(res[7]) # แสดงผลลัพธ์ของ res ตัวที่ 7 คือตำเเหน่งที่เราต้องการ  
    class_list.append(res[7]) # append  คำสั่งเพิ่มข้อมูลลงใน List
    
#car001['namefiles'] = class_list # ตั้งชื่อคอลัมน์ว่า Part ในตาราง pathname โดยนำค่าใน class_list มาใส่
# Out:
# Streaming output truncated to the last 5000 lines.
# left-0831.png
# left-0771.png
# left-0811.png
# left-0801.png
# left-0791.png
# left-0821.png
# left-0781.png
# left-0761.png
# left-0841.png
# left-0871.png
# left-0901.png
# left-0891.png
# left-0911.png
# left-0881.png
# left-0861.png
# left-0851.png
# left-0951.png
# left-0941.png
# left-0921.png
# left-0961.png
# left-1001.png
# left-0971.png
# left-0991.png
# left-0931.png
# left-0981.png
# left-1031.png
# left-1021.png
# left-1071.png
# left-1011.png
# left-1051.png
# left-1091.png
# left-1061.png
# left-1081.png
# left-1041.png
# left-1111.png
# left-1161.png
# left-1121.png
# left-1181.png
# left-1171.png
# left-1101.png
# left-1151.png
# left-1131.png
# left-1141.png
# left-1281.png
# left-1221.png
# left-1261.png
# left-1191.png
# left-1211.png
# left-1241.png
# left-1231.png
# left-1201.png
# left-1271.png
# left-1251.png
# left-1291.png
# left-1301.png
# left-0017.png
# left-0065.png
# left-0001.png
# left-0033.png
# ...

# %%
car
# Out:
#                                               Path_Name
# 0     /content/drive/My Drive/unsup-car-dataset/frei...
# 1     /content/drive/My Drive/unsup-car-dataset/frei...
# 2     /content/drive/My Drive/unsup-car-dataset/frei...
# 3     /content/drive/My Drive/unsup-car-dataset/frei...
# 4     /content/drive/My Drive/unsup-car-dataset/frei...
# ...                                                 ...
# 5831  /content/drive/My Drive/unsup-car-dataset/frei...
# 5832  /content/drive/My Drive/unsup-car-dataset/frei...
# 5833  /content/drive/My Drive/unsup-car-dataset/frei...
# 5834  /content/drive/My Drive/unsup-car-dataset/frei...
# 5835  /content/drive/My Drive/unsup-car-dataset/frei...
#
# [5836 rows x 1 columns]

# %%
list_path = list(car['Path_Name']) # เก็บที่อยู่ของภาพในรูปแบบตาราง โดยชื่อว่า list_path ซึ่ง list(ชื่อตาราง['ชื่อคอลัมน์'])
class_list = list() # สร้างตัวแปร class_list มาเก็บ list ว่าง
for i in list_path: # วนลูปใน list_path
    res = i.split('/') # split ใช้สำหรับแยก โดยในที่นี้แยกด้วย / แล้วตั้งชื่อว่า res
    print(res[6]) # แสดงผลลัพธ์ของ res ตัวที่ 7 คือตำเเหน่งที่เราต้องการ  
    class_list.append(res[6]) # append  คำสั่งเพิ่มข้อมูลลงใน List
    
car['ID'] = class_list # ตั้งชื่อคอลัมน์ว่า Part ในตาราง pathname โดยนำค่าใน class_list มาใส่
# Out:
# Streaming output truncated to the last 5000 lines.
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car048
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# car043
# ...

# %% [markdown]
# # ตารางที่ 1

# %%
car
# Out:
#                                               Path_Name      ID
# 0     /content/drive/My Drive/unsup-car-dataset/frei...  car050
# 1     /content/drive/My Drive/unsup-car-dataset/frei...  car050
# 2     /content/drive/My Drive/unsup-car-dataset/frei...  car050
# 3     /content/drive/My Drive/unsup-car-dataset/frei...  car050
# 4     /content/drive/My Drive/unsup-car-dataset/frei...  car050
# ...                                                 ...     ...
# 5831  /content/drive/My Drive/unsup-car-dataset/frei...  car005
# 5832  /content/drive/My Drive/unsup-car-dataset/frei...  car005
# 5833  /content/drive/My Drive/unsup-car-dataset/frei...  car005
# 5834  /content/drive/My Drive/unsup-car-dataset/frei...  car005
# 5835  /content/drive/My Drive/unsup-car-dataset/frei...  car005
#
# [5836 rows x 2 columns]

# %% [markdown]
# # ตารางที่ 2

# %%
import pandas as pd
import os
import glob
import re

# %%
from google.colab import drive # เชื่อมเข้ากับ Drive
drive.mount('/content/drive')  # คลิกที่ลิงก์ -> เลือก E-mail -> ลงชื่อเข้าใช้ -> ก็อปโค้ด -> นำกลับมาวางในช่องว่าง -> กด enter
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = r'/content/drive/My Drive/annotations'

# %%
file_list = glob.glob(os.path.join(os.getcwd(), path, "*.txt"))

# %%
corpus = []

for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.read())

print(corpus)
# Out:
# ['car001/left-0001.ppm\t3 65 886 346\t3\ncar001/left-0017.ppm\t1 63 874 341\t3\ncar001/left-0033.ppm\t1 56 845 330\t4\ncar001/left-0049.ppm\t6 81 849 361\t7\ncar001/left-0065.ppm\t20 96 859 380\t9\ncar001/left-0081.ppm\t1 127 830 405\t11\ncar001/left-0097.ppm\t1 114 795 392\t14\ncar001/left-0113.ppm\t1 110 778 377\t17\ncar001/left-0129.ppm\t1 121 759 386\t20\ncar001/left-0145.ppm\t28 88 740 354\t24\ncar001/left-0161.ppm\t52 95 748 363\t26\ncar001/left-0177.ppm\t53 122 729 396\t29\ncar001/left-0193.ppm\t99 90 737 353\t32\ncar001/left-0209.ppm\t132 77 749 331\t35\ncar001/left-0225.ppm\t181 84 775 349\t38\ncar001/left-0241.ppm\t251 65 807 332\t42\ncar001/left-0257.ppm\t247 64 776 324\t45\ncar001/left-0273.ppm\t195 70 695 333\t49\ncar001/left-0289.ppm\t270 59 733 321\t52\ncar001/left-0305.ppm\t229 40 666 300\t56\ncar001/left-0321.ppm\t217 78 626 343\t59\ncar001/left-0337.ppm\t214 72 611 336\t62\ncar001/left-0353.ppm\t223 80 616 349\t66\ncar001/left-0369.ppm\t227 63 606 342\t71\ncar001/le
# ...

# %%
res = []
for sub in corpus:
    res.append(sub.replace("\t", "/"))
print(str(res))
# Out:
# ['car001/left-0001.ppm/3 65 886 346/3\ncar001/left-0017.ppm/1 63 874 341/3\ncar001/left-0033.ppm/1 56 845 330/4\ncar001/left-0049.ppm/6 81 849 361/7\ncar001/left-0065.ppm/20 96 859 380/9\ncar001/left-0081.ppm/1 127 830 405/11\ncar001/left-0097.ppm/1 114 795 392/14\ncar001/left-0113.ppm/1 110 778 377/17\ncar001/left-0129.ppm/1 121 759 386/20\ncar001/left-0145.ppm/28 88 740 354/24\ncar001/left-0161.ppm/52 95 748 363/26\ncar001/left-0177.ppm/53 122 729 396/29\ncar001/left-0193.ppm/99 90 737 353/32\ncar001/left-0209.ppm/132 77 749 331/35\ncar001/left-0225.ppm/181 84 775 349/38\ncar001/left-0241.ppm/251 65 807 332/42\ncar001/left-0257.ppm/247 64 776 324/45\ncar001/left-0273.ppm/195 70 695 333/49\ncar001/left-0289.ppm/270 59 733 321/52\ncar001/left-0305.ppm/229 40 666 300/56\ncar001/left-0321.ppm/217 78 626 343/59\ncar001/left-0337.ppm/214 72 611 336/62\ncar001/left-0353.ppm/223 80 616 349/66\ncar001/left-0369.ppm/227 63 606 342/71\ncar001/left-0385.ppm/235 40 628 327/74\ncar001/left-0401.
# ...

# %%
res2 = []
for sub in res:
    res2.append(sub.replace("\n", ","))
print(str(res2))
# Out:
# ['car001/left-0001.ppm/3 65 886 346/3,car001/left-0017.ppm/1 63 874 341/3,car001/left-0033.ppm/1 56 845 330/4,car001/left-0049.ppm/6 81 849 361/7,car001/left-0065.ppm/20 96 859 380/9,car001/left-0081.ppm/1 127 830 405/11,car001/left-0097.ppm/1 114 795 392/14,car001/left-0113.ppm/1 110 778 377/17,car001/left-0129.ppm/1 121 759 386/20,car001/left-0145.ppm/28 88 740 354/24,car001/left-0161.ppm/52 95 748 363/26,car001/left-0177.ppm/53 122 729 396/29,car001/left-0193.ppm/99 90 737 353/32,car001/left-0209.ppm/132 77 749 331/35,car001/left-0225.ppm/181 84 775 349/38,car001/left-0241.ppm/251 65 807 332/42,car001/left-0257.ppm/247 64 776 324/45,car001/left-0273.ppm/195 70 695 333/49,car001/left-0289.ppm/270 59 733 321/52,car001/left-0305.ppm/229 40 666 300/56,car001/left-0321.ppm/217 78 626 343/59,car001/left-0337.ppm/214 72 611 336/62,car001/left-0353.ppm/223 80 616 349/66,car001/left-0369.ppm/227 63 606 342/71,car001/left-0385.ppm/235 40 628 327/74,car001/left-0401.ppm/254 53 668 353/77,car
# ...

# %%
s = str(res2)
s = s.replace(' ', '/')
print(s)
# Out:
77/749/331/35', 'car001/left-0225.ppm/181/84/775/349/38', 'car001/left-0241.ppm/251/65/807/332/42', 'car001/left-0257.ppm/247/64/776/324/45', 'car001/left-0273.ppm/195/70/695/333/49', 'car001/left-0289.ppm/270/59/733/321/52', 'car001/left-0305.ppm/229/40/666/300/56', 'car001/left-0321.ppm/217/78/626/343/59', 'car001/left-0337.ppm/214/72/611/336/62', 'car001/left-0353.ppm/223/80/616/349/66', 'car001/left-0369.ppm/227/63/606/342/71', 'car001/le
# ...

# %%
import pandas as pd

# %%
table = pd.DataFrame({'all':list_1})
table
# Out:
#                                           all
# 0         car001/left-0001.ppm/3/65/886/346/3
# 1         car001/left-0017.ppm/1/63/874/341/3
# 2         car001/left-0033.ppm/1/56/845/330/4
# 3         car001/left-0049.ppm/6/81/849/361/7
# 4        car001/left-0065.ppm/20/96/859/380/9
# ...                                       ...
# 5878   car016/left-2575.ppm/395/65/737/315/68
# 5879   car016/left-2597.ppm/407/76/738/344/74
# 5880  car016/left-2619.ppm/384/122/731/412/79
# 5881  car016/left-2641.ppm/375/125/758/427/84
# 5882
#
# [5883 rows x 1 columns]

# %%
list_path = list(table['all']) # เก็บที่อยู่ของภาพในรูปแบบตาราง โดยชื่อว่า list_path ซึ่ง list(ชื่อตาราง['ชื่อคอลัมน์'])
id_list = list() # สร้างตัวแปร class_list มาเก็บ list ว่าง
for i in list_path: # วนลูปใน list_path
    res = i.split('/') # split ใช้สำหรับแยก โดยในที่นี้แยกด้วย / แล้วตั้งชื่อว่า res
    #print(res[0]) # แสดงผลลัพธ์ของ res ตัวที่ 7 คือตำเเหน่งที่เราต้องการ 
    id_list.append(res[0]) # append  คำสั่งเพิ่มข้อมูลลงใน List
    
table['ID'] = id_list # ตั้งชื่อคอลัมน์ว่า Part ในตาราง pathname โดยนำค่าใน class_list มาใส่

# %%
table
# Out:
#                                           all      ID
# 0         car001/left-0001.ppm/3/65/886/346/3  car001
# 1         car001/left-0017.ppm/1/63/874/341/3  car001
# 2         car001/left-0033.ppm/1/56/845/330/4  car001
# 3         car001/left-0049.ppm/6/81/849/361/7  car001
# 4        car001/left-0065.ppm/20/96/859/380/9  car001
# ...                                       ...     ...
# 5878   car016/left-2575.ppm/395/65/737/315/68  car016
# 5879   car016/left-2597.ppm/407/76/738/344/74  car016
# 5880  car016/left-2619.ppm/384/122/731/412/79  car016
# 5881  car016/left-2641.ppm/375/125/758/427/84  car016
# 5882
#
# [5883 rows x 2 columns]

# %%
list_path = list(table['all']) # เก็บที่อยู่ของภาพในรูปแบบตาราง โดยชื่อว่า list_path ซึ่ง list(ชื่อตาราง['ชื่อคอลัมน์'])
name_list = list() # สร้างตัวแปร class_list มาเก็บ list ว่าง
for i in list_path: # วนลูปใน list_path
    res = i.split('/') # split ใช้สำหรับแยก โดยในที่นี้แยกด้วย / แล้วตั้งชื่อว่า res
    print(res) # แสดงผลลัพธ์ของ res ตัวที่ 7 คือตำเเหน่งที่เราต้องการ 
    #name_list.append(res[1]) # append  คำสั่งเพิ่มข้อมูลลงใน List
    
#table['Name_file'] = name_list # ตั้งชื่อคอลัมน์ว่า Part ในตาราง pathname โดยนำค่าใน class_list มาใส่
# Out:
# Streaming output truncated to the last 5000 lines.
# ['car012', 'left-0438.ppm', '309', '161', '836', '486', '42']
# ['car012', 'left-0461.ppm', '355', '174', '900', '490', '38']
# ['car012', 'left-0484.ppm', '324', '184', '866', '485', '36']
# ['car012', 'left-0507.ppm', '359', '156', '904', '436', '33']
# ['car012', 'left-0530.ppm', '369', '184', '918', '456', '30']
# ['car012', 'left-0553.ppm', '376', '163', '928', '426', '27']
# ['car012', 'left-0576.ppm', '402', '199', '960', '461', '25']
# ['car012', 'left-0599.ppm', '354', '196', '898', '436', '24']
# ['car012', 'left-0622.ppm', '372', '187', '919', '428', '21']
# ['car012', 'left-0645.ppm', '401', '208', '945', '437', '18']
# ['car012', 'left-0668.ppm', '409', '212', '955', '435', '15']
# ['car012', 'left-0691.ppm', '408', '198', '950', '411', '14']
# ['car012', 'left-0714.ppm', '419', '185', '960', '398', '13']
# ['car012', 'left-0737.ppm', '395', '190', '938', '404', '13']
# ...
