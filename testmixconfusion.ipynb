# %% [markdown]
# <a href="https://colab.research.google.com/github/SupidchayaTangkidwanich/prj/blob/main/testmixconfusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive # เชื่อมเข้ากับ Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
import numpy as np

# %%
df = pd.read_csv (r'/content/drive/MyDrive/Newdata/output.csv')
df
# Out:
#           0
# 0    Severe
# 1    Severe
# 2     Minor
# 3     Minor
# 4    Severe
# ..      ...
# 822  Severe
# 823   Minor
# 824  Severe
# 825  Severe
# 826  Severe
#
# [827 rows x 1 columns]

# %%
pred_list = df['0'].values.tolist()
pred_list
# Out:
# ['Severe',
#  'Severe',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Minor',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Moderate',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Moderate',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Moderate',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Moderate',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Moderate',
#  'Minor',
#  'Moderate',
#  'Minor',
#  'Severe',
#  'Minor',
# ...

# %%
df = pd.read_csv (r'/content/drive/MyDrive/Newdata/TTest_Damage.csv')
df
# Out:
#         Unnamed: 0                                          Path_Name  Degree
# 0                0  /content/drive/My Drive/id/id2/Base/p11/dis1.7...    Base
# 1                1  /content/drive/My Drive/id/id2/Base/p11/dis1.7...    Base
# 2                2  /content/drive/My Drive/id/id2/Base/p11/dis1.7...    Base
# 3                3  /content/drive/My Drive/id/id2/Base/p11/dis1.7...    Base
# 4                4  /content/drive/My Drive/id/id2/Base/p11/dis1.7...    Base
# ...            ...                                                ...     ...
# 244350      244350  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244351      244351  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244352      244352  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244353      244353  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244354      244354  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
#
# [244355 rows x 3 columns]

# %%
test = df[df['Unnamed: 0'].between(243528,244354)]
test
# Out:
#         Unnamed: 0                                          Path_Name  Degree
# 243528      243528  /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 243529      243529  /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 243530      243530  /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 243531      243531  /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# 243532      243532  /content/drive/My Drive/Dataset_CDD_v4/trainin...  Severe
# ...            ...                                                ...     ...
# 244350      244350  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244351      244351  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244352      244352  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244353      244353  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
# 244354      244354  /content/drive/My Drive/Dataset_CDD_v4/validat...  Severe
#
# [827 rows x 3 columns]

# %%
act = test['Degree'].tolist() #ค่าจริง
path = test['Path_Name'].tolist() #path

# %%
pred = np.array(pred_list)
act = np.array(act)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# act = data_train['class'].array
# pred = data_train['category_ov'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 41.71704957678355%
#               precision    recall  f1-score   support
#
#         Base       0.00      0.00      0.00         0
#        Minor       0.21      0.57      0.31       144
#     Moderate       0.27      0.07      0.11       238
#       Severe       0.65      0.55      0.60       445
#
#     accuracy                           0.42       827
#    macro avg       0.29      0.30      0.26       827
# weighted avg       0.47      0.42      0.41       827
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(10, 10))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 66.5, 'Predicted label')
