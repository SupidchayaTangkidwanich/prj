# %% [markdown]
# <a href="https://colab.research.google.com/github/SupidchayaTangkidwanich/prj/blob/main/testdamageModel1000mix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive # เชื่อมเข้ากับ Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
import numpy as np

# %%
df = pd.read_csv (r'/content/drive/MyDrive/Newdata/testmodel1000DM.csv')
df
# Out:
#               0
# 0        Severe
# 1      Moderate
# 2         Minor
# 3      Moderate
# 4        Severe
# ...         ...
# 53443    Severe
# 53444    Severe
# 53445    Severe
# 53446      Base
# 53447      Base
#
# [53448 rows x 1 columns]

# %%
pred_list = df['0'].values.tolist()
pred_list
# Out:
# ['Severe',
#  'Moderate',
#  'Minor',
#  'Moderate',
#  'Severe',
#  'Minor',
#  'Base',
#  'Minor',
#  'Base',
#  'Base',
#  'Base',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Base',
#  'Severe',
#  'Moderate',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Base',
#  'Base',
#  'Severe',
#  'Minor',
#  'Moderate',
#  'Minor',
#  'Base',
#  'Severe',
#  'Minor',
#  'Severe',
#  'Severe',
#  'Severe',
#  'Base',
#  'Minor',
#  'Severe',
#  'Minor',
#  'Base',
#  'Moderate',
#  'Minor',
#  'Minor',
#  'Minor',
#  'Minor',
#  'Base',
#  'Severe',
#  'Minor',
#  'Moderate',
#  'Severe',
#  'Severe',
#  'Moderate',
#  'Minor',
#  'Moderate',
#  'Base',
#  'Base',
#  'Minor',
#  'Base',
#  'Severe',
#  'Moderate',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Moderate',
#  'Base',
#  'Severe',
#  'Moderate',
#  'Minor',
#  'Moderate',
#  'Base',
#  'Minor',
#  'Moderate',
#  'Base',
#  'Moderate',
#  'Severe',
#  'Minor',
#  'Minor',
#  'Severe',
#  'Base',
#  'Base',
# ...

# %%
df = pd.read_csv (r'/content/drive/MyDrive/Newdata/id_all.csv')
df
# Out:
#         Unnamed: 0                                          Path_Name    id  \
# 0                0  /content/drive/My Drive/id/id2/Base/p11/dis1.7...   id2
# 1                1  /content/drive/My Drive/id/id2/Base/p11/dis1.7...   id2
# 2                2  /content/drive/My Drive/id/id2/Base/p11/dis1.7...   id2
# 3                3  /content/drive/My Drive/id/id2/Base/p11/dis1.7...   id2
# 4                4  /content/drive/My Drive/id/id2/Base/p11/dis1.7...   id2
# ...            ...                                                ...   ...
# 243523      243523  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243524      243524  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243525      243525  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243526      243526  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243527      243527  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
#
#         Degree
# 0         Base
# 1         Base
# ...

# %%
test = df[df['Unnamed: 0'].between(190080,243527)]
test
# Out:
#         Unnamed: 0                                          Path_Name    id  \
# 190080      190080  /content/drive/My Drive/id/id12/Base/p13/dis1....  id12
# 190081      190081  /content/drive/My Drive/id/id12/Base/p13/dis1....  id12
# 190082      190082  /content/drive/My Drive/id/id12/Base/p13/dis1....  id12
# 190083      190083  /content/drive/My Drive/id/id12/Base/p13/dis1....  id12
# 190084      190084  /content/drive/My Drive/id/id12/Base/p13/dis1....  id12
# ...            ...                                                ...   ...
# 243523      243523  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243524      243524  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243525      243525  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243526      243526  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
# 243527      243527  /content/drive/My Drive/id/id12/Severe/p09/dis...  id12
#
#         Degree
# 190080    Base
# 190081    Base
# ...

# %%
act = test['Degree'].tolist() #ค่าจริง
path = test['Path_Name'].tolist() #path

# %%
pred = np.array(pred_list)
act = np.array(act)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# act = data_train['class'].array
# pred = data_train['category_ov'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 27.252656787906%
#               precision    recall  f1-score   support
#
#         Base       0.26      0.38      0.31     13365
#        Minor       0.26      0.16      0.20     13364
#     Moderate       0.26      0.31      0.28     13354
#       Severe       0.32      0.24      0.27     13365
#
#     accuracy                           0.27     53448
#    macro avg       0.28      0.27      0.27     53448
# weighted avg       0.28      0.27      0.27     53448

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(10, 10))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 66.5, 'Predicted label')
